# %% [markdown]
# <center><b><h1><u>Task 1 </u></h1></b></center>
#
# Create your own Flow Diagram, a subject of your own choice, Example: Fast food order and convert it into code.
#
# Question: Crossing a dual carriage way with two Pelican crossing traffic light.

# %% [markdown]
# <U><center><b>Algorithm and Pseudocode</b></center></U>
#
# STEP 1: Start
#
# STEP 2: Stand on the pavement little way back from the edge
#
# STEP 3: push button and wait for signal opposite
#
# STEP 4: If green light, look bothside for safe window.
#
#      b: else repeat step 3
#
# STEP 5: start crossing
#
# STEP 6: Repeat step 2 to step 4
#
# STEP 7: End

# %% [markdown]
# ![Flowchart1.png](attachment:Flowchart1.png)

# %% [markdown]
# <center><u><h1><b>Task 2</b></h1></u></center>
#
# As an extension to the motorbike task that costs £2000 and loses 10% of its value every year. Set up a function that performs the calculation by passing in parameters. Then using a loop, print the value of the bike every following year until it falls below £1000.

# %%
def cost_lost_procedure():
    bike_cost = 2000
    count = 0
    
    while bike_cost > 1000:
        cur_cost = bike_cost*0.1
        bike_cost = bike_cost - cur_cost
        print('{:.2f}'.format(bike_cost))
        count += 1

# %%
cost_lost_procedure()
# Out:
# 1800.00
# 1620.00
# 1458.00
# 1312.20
# 1180.98
# 1062.88
# 956.59

# %% [markdown]
# <U><center><b>Algorithm and Pseudocode</b></center></U>
#
# STEP 1: Start
#
# STEP 2: Set cost as £2000
#
# STEP 3: Set lost as £2000 * 0.1
#
# STEP 4: If cost is above or equal to £1000 after 1 year/count, cost = cost - lost
#
#              b: print the cost
#
#              c: repeat step 4
#
# Step 5: else get out of the loop
#
# STEP 6: End

# %% [markdown]
# ![Flowchart2.png](attachment:Flowchart2.png)

# %% [markdown]
# <center><u><h1><b>Task 3</b></h1></u></center>
#
# Write a program which will ask for two numbers from a user. Then offer an option menu to the user giving them a choice of mathsoperators. Once the user has selected which operator they wish to use, perform the calculation by using a procedure and passing parameters.

# %%
#A MATHEMATICAL OPERATION FUNCTION
def mat_op_func():
    num1, num2, operand = map(str, input('Enter first and second number followed by a (addition), s (subtraction), d (division), m (multiplication) or p (square each number): ').split(" "))
    num1 = int(num1)
    num2 = int(num2)
    operand = operand.lower()
                              
    if operand == 'a':
        return (f'Sum of {num1} and {num2} is: {num1 + num2}')
    
    elif operand == 's':
        return (f'Difference between {num1} and {num2} is: {num1 - num2}')
    
    elif operand == 'm':
        return (f'Product of {num1} and {num2} is: {num1 * num2}')

    elif operand == 'd':
        return (f'{num1} divided by {num2} is: {num1/num2}')

    elif operand == 'p':
        return (f'{num1} raised to the power of {num2} is: {num1**num2}')

    else:
        return ('Please check that you entered the options correctly, separated by a single space.')

# %%
mat_op_func()
# Out:
# Enter first and second number followed by a (addition), s (subtraction), d (division), m (multiplication) or p (square each number): 4 6 p
# '4 raised to the power of 6 is: 4096'

# %% [markdown]
# <U><center><b>Algorithm and Pseudocode</b></center></U>
#
# STEP 1: Start
#
# STEP 2: Enter first number
#
# STEP 3: Enter second number
#
# STEP 4: Enter math operator (a - addition; s - subtraction; d - division; m - multiplication; or p - square each number)
#
# STEP 5: if math operator is a:
#      5b: print sum of num1 and num2
#
# STEP 6: if math operator is s:
#      6b: print the difference between num1 and num2
#
# STEP 7: if math operator is m:
#      7b: print the product of num1 and num2
#
# STEP 8: if math operator is d:
#      8b: divide num1 by num2 and print
#
# STEP 9: if math operator is p:
#      9b: print num1 raised to the power of num2
#
# STEP 10: else: print check that you entered the right mat_op, go back to step 4
#
# STEP 7: End

# %% [markdown]
# ![Flowchart3.png](attachment:Flowchart3.png)
